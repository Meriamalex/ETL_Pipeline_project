# %%
import csv
import os

def read_csv(file_path):
    # Checking if the file exists
    if not os.path.isfile(file_path):
        print(f"Error: {file_path} not found.")
        return []
    # if file exists, read the data
    with open(file_path, mode='r') as file:
            reader = csv.DictReader(file)
            return list(reader)
   
        
#reading data from all the files and printing first 5 entries
sales_data = read_csv(r'E:\Hero Vired\Python project\sales.csv')
print("Sales Data (first 5 entries):")
print(sales_data[0:5])

products_data = read_csv(r'E:\Hero Vired\Python project\Product.csv')
print("\nProducts Data (first 5 entries):")
print(products_data[0:5])

customers_data = read_csv(r'E:\Hero Vired\Python project\Customer.csv')
print("\nCustomers Data (first 5 entries):")
print(customers_data[0:5])

employees_data = read_csv(r'E:\Hero Vired\Python project\employee.csv')
print("\nEmployees Data (first 5 entries):")
print(employees_data[0:5])
# Out:
# Sales Data (first 5 entries):
# [{'sale_id': '1001', 'date': '01-09-2024', 'customer_id': 'C101', 'product_id': 'P201', 'quantity': '2', 'price': '29.99'}, {'sale_id': '1002', 'date': '02-09-2024', 'customer_id': 'C102', 'product_id': 'P202', 'quantity': '1', 'price': '49.99'}, {'sale_id': '1003', 'date': '02-09-2024', 'customer_id': 'C103', 'product_id': 'P203', 'quantity': '3', 'price': '15.99'}, {'sale_id': '1004', 'date': '03-09-2024', 'customer_id': 'C101', 'product_id': 'P204', 'quantity': '1', 'price': '99.99'}, {'sale_id': '1005', 'date': '04-09-2024', 'customer_id': 'C104', 'product_id': 'P201', 'quantity': '2', 'price': '29.99'}]
#
# Products Data (first 5 entries):
# [{'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'cost_price': '20'}, {'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'cost_price': '35'}, {'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'cost_price': '10'}, {'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'cost_price': '75'}, {'product_id': 'P205', 'product_name': 'Ergonomic Chair', 'category': 'Furniture', 'cost_price': '150'}]
#
# Customers Data (first 5 entries):
# [{'customer_id': 'C101', 'name': 'Alex Johnson', 'email': 'alex.johnson@example.com', 'address': '101 Maple Street', 'join_date': '15-01-2023'}, {'customer_id': 'C102', 'name': 'Emily Davis', 'email': 'emily.davis@example.com', 'address': '202 Oak Avenue', 'join_date': '22-01-2023'}, {'customer_id': 'C103', 'name': 'Michael Brown', 'email': 'michael.brown@example.com', 'address': '303 Pine Road', 'join_date': '29-01-2023'}, {'customer_id': 'C104', 'name': 'Sophia Wilson', 'email': 'sophia.wilson@example.com', 'address': '404 Cedar Lane', 'join_date': '05-02-2023'}, {'customer_id': 'C105', 'name': 'Daniel Smith', 'email': 'daniel.smith@example.com', 'address': '505 Birch Drive', 'join_date': '12-02-2023'}]
#
# Employees Data (first 5 entries):
# [{'employee_id': 'E001', 'name': 'Emily Johnson', 'department': 'Sales', 'hire_date': '15-01-2018', 'salary': '65000'}, {'employee_id': 'E002', 'name': 'Michael Smith', 'department': 'Marketing', 'hire_date': '22-03-2019', 'salary': '60000'}, {'employee_id': 'E003', 'name': 'Jessica Williams', 'department': 'Finance', 'hire_date': '10-06-2017', 'salary': '70000'}, {'employee_id': 'E004', 'name': 'David Brown', 'department': 'IT', 'hire_date': '05-08-2020', 'salary': '75000'}, {'employee_id': 'E005', 'name': 'Sarah Davis', 'department': 'Human Resources', 'hire_date': '30-11-2016', 'salary': '68000'}]

# %%
def check_for_missing_values(data, dataset_name):
    missing_found = False  # Flag to track if any missing values are found
    
    for i, row in enumerate(data):  # Iterate over each row in the dataset
        for key, value in row.items():  # Iterate over each key (column) in the row
            if value is None or value == '':  # Check for None or empty string
                print(f"Missing value found in row {i + 1}, column '{key}': {value}")
                missing_found = True  # Set the flag to True if a missing value is found
    
    if not missing_found:
        print("No missing values found in the dataset.")

check_for_missing_values(sales_data, "sales_data")
check_for_missing_values(products_data, "products_data")
check_for_missing_values(customers_data, "customers_data")
check_for_missing_values(employees_data, "employees_data")
# Out:
# No missing values found in the dataset.
# No missing values found in the dataset.
# Missing value found in row 1, column 'join_date': None
# Missing value found in row 2, column 'join_date': None
# Missing value found in row 3, column 'join_date': None
# Missing value found in row 4, column 'join_date': None
# Missing value found in row 5, column 'join_date': None
# Missing value found in row 6, column 'join_date': None
# Missing value found in row 7, column 'join_date': None
# Missing value found in row 8, column 'join_date': None
# Missing value found in row 9, column 'join_date': None
# Missing value found in row 10, column 'join_date': None
# Missing value found in row 11, column 'join_date': None
# Missing value found in row 12, column 'join_date': None
# Missing value found in row 13, column 'join_date': None
# Missing value found in row 14, column 'join_date': None
# Missing value found in row 15, column 'join_date': None
# Missing value found in row 16, column 'join_date': None
# Missing value found in row 17, column 'join_date': None
# Missing value found in row 18, column 'join_date': None
# Missing value found in row 19, column 'join_date': None
# Missing value found in row 20, column 'join_date': None
# Missing value found in row 21, column 'join_date': None
# Missing value found in row 22, column 'join_date': None
# Missing value found in row 23, column 'join_date': None
# Missing value found in row 24, column 'join_date': None
# Missing value found in row 25, column 'join_date': None
# Missing value found in row 26, column 'join_date': None
# Missing value found in row 27, column 'join_date': None
# Missing value found in row 28, column 'join_date': None
# Missing value found in row 29, column 'join_date': None
# Missing value found in row 30, column 'join_date': None
# Missing value found in row 31, column 'join_date': None
# Missing value found in row 32, column 'join_date': None
# Missing value found in row 33, column 'join_date': None
# Missing value found in row 34, column 'join_date': None
# Missing value found in row 35, column 'join_date': None
# Missing value found in row 36, column 'join_date': None
# Missing value found in row 37, column 'join_date': None
# Missing value found in row 38, column 'join_date': None
# Missing value found in row 39, column 'join_date': None
# Missing value found in row 40, column 'join_date': None
# Missing value found in row 41, column 'join_date': None
# Missing value found in row 42, column 'join_date': None
# Missing value found in row 43, column 'join_date': None
# Missing value found in row 44, column 'join_date': None
# Missing value found in row 45, column 'join_date': None
# Missing value found in row 46, column 'join_date': None
# Missing value found in row 47, column 'join_date': None
# Missing value found in row 48, column 'join_date': None
# Missing value found in row 49, column 'join_date': None
# Missing value found in row 50, column 'join_date': None
# Missing value found in row 51, column 'join_date': None
# Missing value found in row 52, column 'join_date': None
# Missing value found in row 53, column 'join_date': None
# Missing value found in row 54, column 'join_date': None
# Missing value found in row 55, column 'join_date': None
# Missing value found in row 56, column 'join_date': None
# Missing value found in row 57, column 'join_date': None
# Missing value found in row 58, column 'join_date': None
# Missing value found in row 59, column 'join_date': None
# Missing value found in row 60, column 'join_date': None
# Missing value found in row 61, column 'join_date': None
# Missing value found in row 62, column 'join_date': None
# Missing value found in row 63, column 'join_date': None
# Missing value found in row 64, column 'join_date': None
# Missing value found in row 65, column 'join_date': None
# Missing value found in row 66, column 'join_date': None
# Missing value found in row 67, column 'join_date': None
# Missing value found in row 68, column 'join_date': None
# Missing value found in row 69, column 'join_date': None
# Missing value found in row 70, column 'join_date': None
# Missing value found in row 71, column 'join_date': None
# Missing value found in row 72, column 'join_date': None
# Missing value found in row 73, column 'join_date': None
# Missing value found in row 74, column 'join_date': None
# Missing value found in row 75, column 'join_date': None
# Missing value found in row 76, column 'join_date': None
# Missing value found in row 77, column 'join_date': None
# Missing value found in row 78, column 'join_date': None
# Missing value found in row 79, column 'join_date': None
# Missing value found in row 80, column 'join_date': None
# Missing value found in row 81, column 'join_date': None
# Missing value found in row 82, column 'join_date': None
# Missing value found in row 83, column 'join_date': None
# Missing value found in row 84, column 'join_date': None
# Missing value found in row 85, column 'join_date': None
# Missing value found in row 86, column 'join_date': None
# Missing value found in row 87, column 'join_date': None
# Missing value found in row 88, column 'join_date': None
# Missing value found in row 89, column 'join_date': None
# Missing value found in row 90, column 'join_date': None
# Missing value found in row 91, column 'join_date': None
# Missing value found in row 92, column 'join_date': None
# Missing value found in row 93, column 'join_date': None
# Missing value found in row 94, column 'join_date': None
# Missing value found in row 95, column 'join_date': None
# Missing value found in row 96, column 'join_date': None
# Missing value found in row 97, column 'join_date': None
# Missing value found in row 98, column 'join_date': None
# Missing value found in row 99, column 'join_date': None
# Missing value found in row 100, column 'join_date': None
# Missing value found in row 1, column 'hire_date': None
# Missing value found in row 2, column 'hire_date': None
# Missing value found in row 3, column 'hire_date': None
# Missing value found in row 4, column 'hire_date': None
# Missing value found in row 5, column 'hire_date': None
# Missing value found in row 6, column 'hire_date': None
# Missing value found in row 7, column 'hire_date': None
# Missing value found in row 8, column 'hire_date': None
# Missing value found in row 9, column 'hire_date': None
# Missing value found in row 10, column 'hire_date': None
# Missing value found in row 11, column 'hire_date': None
# Missing value found in row 12, column 'hire_date': None
# Missing value found in row 13, column 'hire_date': None
# Missing value found in row 14, column 'hire_date': None
# Missing value found in row 15, column 'hire_date': None
# Missing value found in row 16, column 'hire_date': None
# Missing value found in row 17, column 'hire_date': None
# Missing value found in row 18, column 'hire_date': None
# Missing value found in row 19, column 'hire_date': None
# Missing value found in row 20, column 'hire_date': None
# Missing value found in row 21, column 'hire_date': None
# Missing value found in row 22, column 'hire_date': None
# Missing value found in row 23, column 'hire_date': None
# Missing value found in row 24, column 'hire_date': None
# Missing value found in row 25, column 'hire_date': None
# Missing value found in row 26, column 'hire_date': None
# Missing value found in row 27, column 'hire_date': None
# Missing value found in row 28, column 'hire_date': None
# Missing value found in row 29, column 'hire_date': None
# Missing value found in row 30, column 'hire_date': None
# Missing value found in row 31, column 'hire_date': None
# Missing value found in row 32, column 'hire_date': None
# Missing value found in row 33, column 'hire_date': None
# Missing value found in row 34, column 'hire_date': None
# Missing value found in row 35, column 'hire_date': None
# Missing value found in row 36, column 'hire_date': None
# Missing value found in row 37, column 'hire_date': None
# Missing value found in row 38, column 'hire_date': None
# Missing value found in row 39, column 'hire_date': None
# Missing value found in row 40, column 'hire_date': None
# Missing value found in row 41, column 'hire_date': None
# Missing value found in row 42, column 'hire_date': None
# Missing value found in row 43, column 'hire_date': None
# Missing value found in row 44, column 'hire_date': None
# Missing value found in row 45, column 'hire_date': None
# Missing value found in row 46, column 'hire_date': None
# Missing value found in row 47, column 'hire_date': None
# Missing value found in row 48, column 'hire_date': None
# Missing value found in row 49, column 'hire_date': None
# Missing value found in row 50, column 'hire_date': None
# Missing value found in row 51, column 'hire_date': None
# Missing value found in row 52, column 'hire_date': None
# Missing value found in row 53, column 'hire_date': None
# Missing value found in row 54, column 'hire_date': None
# Missing value found in row 55, column 'hire_date': None
# Missing value found in row 56, column 'hire_date': None
# Missing value found in row 57, column 'hire_date': None
# Missing value found in row 58, column 'hire_date': None
# Missing value found in row 59, column 'hire_date': None
# Missing value found in row 60, column 'hire_date': None
# Missing value found in row 61, column 'hire_date': None

# %%
#function to count missing values
def count_missing_values(data):
    missing_count = 0
    for row in data:
        for key in row:
            if row[key] == '':  # Check for empty strings
                missing_count += 1
    return missing_count

# Count missing values before handling
print("Missing values before handling:")
print(f"Sales Data: {count_missing_values(sales_data)}")
print(f"Products Data: {count_missing_values(products_data)}")
print(f"Customers Data: {count_missing_values(customers_data)}")
print(f"Employees Data: {count_missing_values(employees_data)}")

# Handle missing values
sales_data = handle_missing_values(sales_data)
products_data = handle_missing_values(products_data)
customers_data = handle_missing_values(customers_data)
employees_data = handle_missing_values(employees_data)


# Count missing values after handling
print("\nMissing values after handling:")
print(f"Sales Data: {count_missing_values(sales_data)}")
print(f"Products Data: {count_missing_values(products_data)}")
print(f"Customers Data: {count_missing_values(customers_data)}")
print(f"Employees Data: {count_missing_values(employees_data)}")
# Out:
# Missing values before handling:
# Sales Data: 0
# Products Data: 0
# Customers Data: 0
# Employees Data: 0
#
# Missing values after handling:
# Sales Data: 0
# Products Data: 0
# Customers Data: 0
# Employees Data: 0

# %%
from datetime import datetime
import csv

def convert_value(value, target_type):
    """Convert value to the specified target type."""
    if value is None or value == '':
        return None  # or some default value if you prefer
    try:
        if target_type == int:
            return int(value)
        elif target_type == float:
            return float(value)
        elif target_type == datetime:
            if isinstance(value, str):
                print(f"Converting date: {value}")
                # Check if value is a string
                return datetime.strptime(value, '%d-%m-%Y')  # Adjust format as needed
            else:
                return None  # Return None if value is not a string
        else:
            return str(value)  # Default to string for any other type
    except ValueError as e:
        print(f"Error converting value '{value}' to {target_type}: {e}")
        return None 

def convert_data_types(sales_data, products_data, customers_data, employees_data):
    # Convert data types for sales_data
    for row in sales_data:
        row['sale_id'] = convert_value(row['sale_id'], int)  # Assuming sale_id is still an integer
        row['customer_id'] = str(row['customer_id'])  # Keep customer_id as a string
        row['product_id'] = str(row['product_id'])  # Keep product_id as a string
        row['quantity'] = convert_value(row['quantity'], int)
        row['price'] = convert_value(row['price'], float)
        row['date'] = convert_value(row['date'], datetime)

    # Convert data types for products_data
    for row in products_data:
        row['product_id'] = str(row['product_id'])  # Keep product_id as a string
        row['product_name'] = convert_value(row['product_name'], str)
        row['category'] = convert_value(row['category'], str)
        row['cost_price'] = convert_value(row['cost_price'], float)

    # Convert data types for customers_data
    for row in customers_data:
        row['customer_id'] = str(row['customer_id'])  # Keep customer_id as a string
        row['name'] = convert_value(row['name'], str)
        row['email'] = convert_value(row['email'], str)
        row['address'] = convert_value(row['address'], str)
        row['join_date'] = convert_value(row['join_date'], datetime)

    # Convert data types for employees_data
    for row in employees_data:
        row['employee_id'] = convert_value(row['employee_id'], int)  # Assuming employee_id is still an integer
        row['name'] = convert_value(row['name'], str)
        row['department'] = convert_value(row['department'], str)
        row['hire_date'] = convert_value(row['hire_date'], datetime)
        row['salary'] = convert_value(row['salary'], float)


# Correct data types
convert_data_types(sales_data, products_data, customers_data, employees_data)
print("First 5 rows of sales_data:")
for row in sales_data[:5]:
    print(row)
# Out:
# First 5 rows of sales_data:
# {'sale_id': 1001, 'date': None, 'customer_id': 'C101', 'product_id': 'P201', 'quantity': 2, 'price': 29.99}
# {'sale_id': 1002, 'date': None, 'customer_id': 'C102', 'product_id': 'P202', 'quantity': 1, 'price': 49.99}
# {'sale_id': 1003, 'date': None, 'customer_id': 'C103', 'product_id': 'P203', 'quantity': 3, 'price': 15.99}
# {'sale_id': 1004, 'date': None, 'customer_id': 'C101', 'product_id': 'P204', 'quantity': 1, 'price': 99.99}
# {'sale_id': 1005, 'date': None, 'customer_id': 'C104', 'product_id': 'P201', 'quantity': 2, 'price': 29.99}

# %%
def integrate_data(sales_data, products_data, customers_data):
    # Create lookup dictionaries for products, customers, and employees
    product_lookup = {p['product_id']: p for p in products_data}
    customer_lookup = {c['customer_id']: c for c in customers_data}

    integrated_data = []
    for sale in sales_data:
        product = product_lookup.get(sale['product_id'], {})
        customer = customer_lookup.get(sale['customer_id'], {})
         # Employee info cant be retrieved as there is nothing common in sales and employee files.

        if product and customer:  # Ensure all mappings exist
            total_amount = int(sale['quantity']) * float(sale['price'])
            cost_price = product['cost_price']
            profit_margin = (total_amount - (cost_price * int(sale['quantity']))) / total_amount

            integrated_data.append({
                "sale_id": sale['sale_id'],
                "date": sale['date'],
                "customer_id": sale['customer_id'],
                "quantity": int(sale['quantity']),
                "price": float(sale['price']),
                "product_id": sale['product_id'],
                "product_name": product['product_name'],
                "category": product['category'],
                "customer_name": customer['name'],
                "total_amount": total_amount,
                "profit_margin": profit_margin,
            })

    return integrated_data

# Integrate the data
integrated_sales_data = integrate_data(sales_data, products_data, customers_data)

# Print the first 5 entries of the integrated data
print("Integrated Sales Data (first 5 entries):")
for record in integrated_sales_data[:5]:  # Slicing to get the first 5 records
    print(record)
# Out:
# Integrated Sales Data (first 5 entries):
# {'sale_id': 1001, 'date': None, 'customer_id': 'C101', 'quantity': 2, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Alex Johnson', 'total_amount': 59.98, 'profit_margin': 0.3331110370123374}
# {'sale_id': 1002, 'date': None, 'customer_id': 'C102', 'quantity': 1, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'Emily Davis', 'total_amount': 49.99, 'profit_margin': 0.2998599719943989}
# {'sale_id': 1003, 'date': None, 'customer_id': 'C103', 'quantity': 3, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Michael Brown', 'total_amount': 47.97, 'profit_margin': 0.37460913070669166}
# {'sale_id': 1004, 'date': None, 'customer_id': 'C101', 'quantity': 1, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'Alex Johnson', 'total_amount': 99.99, 'profit_margin': 0.24992499249924988}
# {'sale_id': 1005, 'date': None, 'customer_id': 'C104', 'quantity': 2, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Sophia Wilson', 'total_amount': 59.98, 'profit_margin': 0.3331110370123374}

# %%
from datetime import datetime, timedelta


sales_data = read_csv(r'E:\Hero Vired\Python project\sales.csv')


def create_date_dimension(sales_data):
    # Extract the date range from sales data
    min_date = min(datetime.strptime(row['date'], '%d-%m-%Y') for row in sales_data)
    max_date = max(datetime.strptime(row['date'], '%d-%m-%Y') for row in sales_data)

    # Initialize an empty list to hold the date dimension
    date_dimension = []

    # Loop through each date in the range
    current_date = min_date
    while current_date <= max_date:
        # Extract attributes
        year = current_date.year
        month = current_date.month
        month_name = current_date.strftime('%B')
        quarter = (month - 1) // 3 + 1
        day = current_date.day
        day_of_week = current_date.weekday()  # Monday=0, Sunday=6
        day_name = current_date.strftime('%A')
        is_weekend = day_of_week >= 5  # Saturday=5, Sunday=6

        # Append the attributes as a dictionary
        date_dimension.append({
            'date': current_date.strftime('%d-%m-%Y'),  # Format date as string
            'year': year,
            'month': month,
            'month_name': month_name,
            'quarter': quarter,
            'day': day,
            'day_of_week': day_of_week,
            'day_name': day_name,
            'is_weekend': is_weekend
        })

        # Move to the next day
        current_date += timedelta(days=1)

    return date_dimension

# Create the date dimension
date_dimension_list = create_date_dimension(sales_data)



# Print the first 5 entries of the date dimension
print("Date Dimension (first 5 entries):")
for entry in date_dimension_list[:5]:
    print (entry)
# Out:
# Date Dimension (first 5 entries):
# {'date': '01-09-2024', 'year': 2024, 'month': 9, 'month_name': 'September', 'quarter': 3, 'day': 1, 'day_of_week': 6, 'day_name': 'Sunday', 'is_weekend': True}
# {'date': '02-09-2024', 'year': 2024, 'month': 9, 'month_name': 'September', 'quarter': 3, 'day': 2, 'day_of_week': 0, 'day_name': 'Monday', 'is_weekend': False}
# {'date': '03-09-2024', 'year': 2024, 'month': 9, 'month_name': 'September', 'quarter': 3, 'day': 3, 'day_of_week': 1, 'day_name': 'Tuesday', 'is_weekend': False}
# {'date': '04-09-2024', 'year': 2024, 'month': 9, 'month_name': 'September', 'quarter': 3, 'day': 4, 'day_of_week': 2, 'day_name': 'Wednesday', 'is_weekend': False}
# {'date': '05-09-2024', 'year': 2024, 'month': 9, 'month_name': 'September', 'quarter': 3, 'day': 5, 'day_of_week': 3, 'day_name': 'Thursday', 'is_weekend': False}

# %%
# Function to write a CSV file
def write_csv(file_path, data, fieldnames):
    with open(file_path, mode='w', newline='') as file:
        writer = csv.DictWriter(file, fieldnames=fieldnames)
        writer.writeheader()
        writer.writerows(data)

# Generate comprehensive sales report
comprehensive_report_path = r'E:\Hero Vired\Python project\comprehensive_sales_report.csv'
write_csv(comprehensive_report_path, integrated_sales_data, integrated_sales_data[0].keys())
print(f"Comprehensive sales report generated at: {comprehensive_report_path}")

# Generate summary report
summary_report = []
summary_lookup = {}

for record in integrated_sales_data:
    customer_id = record['customer_id']
    product_id = record['product_id']
    total_amount = record['total_amount']
    quantity = record['quantity']

    # Create a unique key for each customer-product combination
    key = (customer_id, product_id)

    if key not in summary_lookup:
        summary_lookup[key] = {
            'customer_id': customer_id,
            'customer_name': record['customer_name'],
            'product_id': product_id,
            'product_name': record['product_name'],
            'total_sales': 0,
            'total_quantity': 0
        }

    summary_lookup[key]['total_sales'] += total_amount
    summary_lookup[key]['total_quantity'] += quantity

# Convert summary lookup to a list
for key, summary in summary_lookup.items():
    summary_report.append({
        'customer_id': summary['customer_id'],
        'customer_name': summary['customer_name'],
        'product_id': summary['product_id'],
        'product_name': summary['product_name'],
        'total_sales': summary['total_sales'],
        'total_quantity': summary['total_quantity']
    })

# Write summary report to CSV
summary_report_path = r'E:\Hero Vired\Python project\summary_sales_report.csv'
write_csv(summary_report_path, summary_report, summary_report[0].keys())
print(f"Summary sales report generated at: {summary_report_path}")
# Out:
# Comprehensive sales report generated at: E:\Hero Vired\Python project\comprehensive_sales_report.csv
# Summary sales report generated at: E:\Hero Vired\Python project\summary_sales_report.csv

# %%
from collections import defaultdict
from datetime import datetime
# Create a lookup dictionary for products
product_lookup = {p['product_id']: p for p in products_data}

# Data Analysis

# 1. Calculate total sales and profit by product category
category_sales = defaultdict(lambda: {'total_sales': 0, 'total_profit': 0})

for record in integrated_sales_data:
    category = record['category']
    total_amount = record['total_amount']
    
    # Use the product_id to get the product details from the lookup dictionary
    product = product_lookup.get(record['product_id'], {})
    cost_price = float(product.get('cost_price', 0))  # Default to 0 if not found
    profit = total_amount - (cost_price * record['quantity'])

    category_sales[category]['total_sales'] += total_amount
    category_sales[category]['total_profit'] += profit

print("\nTotal Sales and Profit by Product Category:")
for category, values in category_sales.items():
    print(f"Category: {category}, Total Sales: {values['total_sales']:.2f}, Total Profit: {values['total_profit']:.2f}")

# 2. Identify top-selling products
product_sales = defaultdict(lambda: {'total_sales': 0, 'total_quantity': 0})

for record in integrated_sales_data:
    product_id = record['product_id']
    total_amount = record['total_amount']
    quantity = record['quantity']

    product_sales[product_id]['total_sales'] += total_amount
    product_sales[product_id]['total_quantity'] += quantity

top_selling_products = sorted(product_sales.items(), key=lambda x: x[1]['total_sales'], reverse=True)[:5]

print("\nTop-Selling Products:")
for product_id, values in top_selling_products:
    product_name = product_lookup.get(product_id, {}).get('product_name', 'Unknown')  # Use lookup dictionary
    print(f"Product: {product_name}, Total Sales: {values['total_sales']:.2f}, Total Quantity: {values['total_quantity']}")

# 3. Identify key customers
customer_sales = defaultdict(lambda: {'total_sales': 0, 'total_quantity': 0})

for record in integrated_sales_data:
    customer_id = record['customer_id']
    total_amount = record['total_amount']
    quantity = record['quantity']

    customer_sales[customer_id]['total_sales'] += total_amount
    customer_sales[customer_id]['total_quantity'] += quantity

key_customers = sorted(customer_sales.items(), key=lambda x: x[1]['total_sales'], reverse=True)[:5]

print("\nKey Customers:")
for customer_id, values in key_customers:
    customer_name = next((c['name'] for c in customers_data if c['customer_id'] == customer_id), "Unknown")
    print(f"Customer ID: {customer_id}, Name: {customer_name}, Total Sales: {values['total_sales']:.2f}, Total Quantity: {values['total_quantity']}")
# 4. Analyze sales trends over time (daily, monthly, quarterly).
    
# Initialize dictionaries to hold sales data for trends
daily_sales = defaultdict(float)
monthly_sales = defaultdict(float)
quarterly_sales = defaultdict(float)

# Iterate through the integrated sales data to calculate sales trends
for record in integrated_sales_data:
    date = record.get('date')  # Safely get the date
    if date is None:
        print("Warning: Date is None for record:", record)
        continue  # Skip this record

    # Convert date from dd-mm-yyyy to yyyy-mm-dd
    try:
        date_obj = datetime.strptime(date, '%d-%m-%Y')
        formatted_date = date_obj.strftime('%Y-%m-%d')
    except ValueError as e:
        print(f"Error parsing date '{date}': {e}")
        continue  # Skip this record if date parsing fails

    # Daily sales
    daily_sales[formatted_date] += record['total_amount']

    # Monthly sales
    month = formatted_date[:7]  # Extract YYYY-MM format
    monthly_sales[month] += record['total_amount']

    # Quarterly sales
    year = formatted_date[:4]
    month_num = int(formatted_date[5:7])
    quarter = (month_num - 1) // 3 + 1
    quarterly_key = f"{year}-Q{quarter}"
    quarterly_sales[quarterly_key] += record['total_amount']

# Print daily sales trends
print("\nDaily Sales Trends:")
for date, total in sorted(daily_sales.items()):
    print(f"Date: {date}, Total Sales: {total:.2f}")

# Print monthly sales trends
print("\nMonthly Sales Trends:")
for month, total in sorted(monthly_sales.items()):
    print(f"Month: {month}, Total Sales: {total:.2f}")

# Print quarterly sales trends
print("\nQuarterly Sales Trends:")
for quarter, total in sorted(quarterly_sales.items()):
    print(f"Quarter: {quarter}, Total Sales: {total:.2f}")
# Out:
# Total Sales and Profit by Product Category:
# Category: Electronics, Total Sales: 12108.18, Total Profit: 3243.18
# Category: Home & Office, Total Sales: 4649.07, Total Profit: 1394.07
# Category: Stationery, Total Sales: 1439.10, Total Profit: 539.10
#
# Top-Selling Products:
# Product: Bluetooth Speaker, Total Sales: 9499.05, Total Quantity: 95
# Product: LED Desk Lamp, Total Sales: 4649.07, Total Quantity: 93
# Product: Wireless Mouse, Total Sales: 2609.13, Total Quantity: 87
# Product: Notebook Set, Total Sales: 1439.10, Total Quantity: 90
#
# Key Customers:
# Customer ID: C123, Name: Jackson Carter, Total Sales: 999.90, Total Quantity: 10
# Customer ID: C111, Name: William Young, Total Sales: 799.92, Total Quantity: 8
# Customer ID: C107, Name: Matthew Clark, Total Sales: 599.94, Total Quantity: 6
# Customer ID: C119, Name: Jacob Adams, Total Sales: 599.94, Total Quantity: 6
# Customer ID: C103, Name: Michael Brown, Total Sales: 547.92, Total Quantity: 8
# Warning: Date is None for record: {'sale_id': 1001, 'date': None, 'customer_id': 'C101', 'quantity': 2, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Alex Johnson', 'total_amount': 59.98, 'profit_margin': 0.3331110370123374}
# Warning: Date is None for record: {'sale_id': 1002, 'date': None, 'customer_id': 'C102', 'quantity': 1, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'Emily Davis', 'total_amount': 49.99, 'profit_margin': 0.2998599719943989}
# Warning: Date is None for record: {'sale_id': 1003, 'date': None, 'customer_id': 'C103', 'quantity': 3, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Michael Brown', 'total_amount': 47.97, 'profit_margin': 0.37460913070669166}
# Warning: Date is None for record: {'sale_id': 1004, 'date': None, 'customer_id': 'C101', 'quantity': 1, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'Alex Johnson', 'total_amount': 99.99, 'profit_margin': 0.24992499249924988}
# Warning: Date is None for record: {'sale_id': 1005, 'date': None, 'customer_id': 'C104', 'quantity': 2, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Sophia Wilson', 'total_amount': 59.98, 'profit_margin': 0.3331110370123374}
# Warning: Date is None for record: {'sale_id': 1006, 'date': None, 'customer_id': 'C105', 'quantity': 4, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'Daniel Smith', 'total_amount': 199.96, 'profit_margin': 0.2998599719943989}
# Warning: Date is None for record: {'sale_id': 1007, 'date': None, 'customer_id': 'C106', 'quantity': 1, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Olivia Martin', 'total_amount': 15.99, 'profit_margin': 0.3746091307066917}
# Warning: Date is None for record: {'sale_id': 1008, 'date': None, 'customer_id': 'C107', 'quantity': 5, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'Matthew Clark', 'total_amount': 499.95, 'profit_margin': 0.2499249924992499}
# Warning: Date is None for record: {'sale_id': 1009, 'date': None, 'customer_id': 'C108', 'quantity': 2, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Isabella Lewis', 'total_amount': 59.98, 'profit_margin': 0.3331110370123374}
# Warning: Date is None for record: {'sale_id': 1010, 'date': None, 'customer_id': 'C109', 'quantity': 3, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'Ethan Walker', 'total_amount': 149.97, 'profit_margin': 0.2998599719943989}
# Warning: Date is None for record: {'sale_id': 1011, 'date': None, 'customer_id': 'C110', 'quantity': 2, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Mia Hall', 'total_amount': 31.98, 'profit_margin': 0.3746091307066917}
# Warning: Date is None for record: {'sale_id': 1012, 'date': None, 'customer_id': 'C111', 'quantity': 4, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'William Young', 'total_amount': 399.96, 'profit_margin': 0.24992499249924988}
# Warning: Date is None for record: {'sale_id': 1013, 'date': None, 'customer_id': 'C112', 'quantity': 1, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Ava Hernandez', 'total_amount': 29.99, 'profit_margin': 0.3331110370123374}
# Warning: Date is None for record: {'sale_id': 1014, 'date': None, 'customer_id': 'C113', 'quantity': 5, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'James King', 'total_amount': 249.95000000000002, 'profit_margin': 0.29985997199439895}
# Warning: Date is None for record: {'sale_id': 1015, 'date': None, 'customer_id': 'C114', 'quantity': 3, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Charlotte Wright', 'total_amount': 47.97, 'profit_margin': 0.37460913070669166}
# Warning: Date is None for record: {'sale_id': 1016, 'date': None, 'customer_id': 'C115', 'quantity': 2, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'Logan Lopez', 'total_amount': 199.98, 'profit_margin': 0.24992499249924988}
# Warning: Date is None for record: {'sale_id': 1017, 'date': None, 'customer_id': 'C116', 'quantity': 4, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Amelia Hill', 'total_amount': 119.96, 'profit_margin': 0.3331110370123374}
# Warning: Date is None for record: {'sale_id': 1018, 'date': None, 'customer_id': 'C117', 'quantity': 1, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'Benjamin Scott', 'total_amount': 49.99, 'profit_margin': 0.2998599719943989}
# Warning: Date is None for record: {'sale_id': 1019, 'date': None, 'customer_id': 'C118', 'quantity': 5, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Evelyn Green', 'total_amount': 79.95, 'profit_margin': 0.3746091307066917}
# Warning: Date is None for record: {'sale_id': 1020, 'date': None, 'customer_id': 'C119', 'quantity': 3, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'Jacob Adams', 'total_amount': 299.96999999999997, 'profit_margin': 0.24992499249924985}
# Warning: Date is None for record: {'sale_id': 1022, 'date': None, 'customer_id': 'C121', 'quantity': 4, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'Alexander Gonzalez', 'total_amount': 199.96, 'profit_margin': 0.2998599719943989}
# Warning: Date is None for record: {'sale_id': 1023, 'date': None, 'customer_id': 'C122', 'quantity': 1, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Abigail Nelson', 'total_amount': 15.99, 'profit_margin': 0.3746091307066917}
# Warning: Date is None for record: {'sale_id': 1024, 'date': None, 'customer_id': 'C123', 'quantity': 5, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'Jackson Carter', 'total_amount': 499.95, 'profit_margin': 0.2499249924992499}
# Warning: Date is None for record: {'sale_id': 1025, 'date': None, 'customer_id': 'C124', 'quantity': 3, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Emily Mitchell', 'total_amount': 89.97, 'profit_margin': 0.33311103701233746}
# Warning: Date is None for record: {'sale_id': 1026, 'date': None, 'customer_id': 'C125', 'quantity': 2, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'Liam Perez', 'total_amount': 99.98, 'profit_margin': 0.2998599719943989}
# Warning: Date is None for record: {'sale_id': 1027, 'date': None, 'customer_id': 'C126', 'quantity': 4, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Sophia Roberts', 'total_amount': 63.96, 'profit_margin': 0.3746091307066917}
# Warning: Date is None for record: {'sale_id': 1028, 'date': None, 'customer_id': 'C127', 'quantity': 1, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'Noah Turner', 'total_amount': 99.99, 'profit_margin': 0.24992499249924988}
# Warning: Date is None for record: {'sale_id': 1029, 'date': None, 'customer_id': 'C128', 'quantity': 5, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Grace Phillips', 'total_amount': 149.95, 'profit_margin': 0.3331110370123374}
# Warning: Date is None for record: {'sale_id': 1030, 'date': None, 'customer_id': 'C129', 'quantity': 3, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'Elijah Campbell', 'total_amount': 149.97, 'profit_margin': 0.2998599719943989}
# Warning: Date is None for record: {'sale_id': 1031, 'date': None, 'customer_id': 'C130', 'quantity': 2, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Chloe Parker', 'total_amount': 31.98, 'profit_margin': 0.3746091307066917}
# Warning: Date is None for record: {'sale_id': 1032, 'date': None, 'customer_id': 'C131', 'quantity': 4, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'Aiden Evans', 'total_amount': 399.96, 'profit_margin': 0.24992499249924988}
# Warning: Date is None for record: {'sale_id': 1033, 'date': None, 'customer_id': 'C132', 'quantity': 1, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Victoria Edwards', 'total_amount': 29.99, 'profit_margin': 0.3331110370123374}
# Warning: Date is None for record: {'sale_id': 1034, 'date': None, 'customer_id': 'C133', 'quantity': 5, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'Lucas Collins', 'total_amount': 249.95000000000002, 'profit_margin': 0.29985997199439895}
# Warning: Date is None for record: {'sale_id': 1035, 'date': None, 'customer_id': 'C134', 'quantity': 3, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Penelope Stewart', 'total_amount': 47.97, 'profit_margin': 0.37460913070669166}
# Warning: Date is None for record: {'sale_id': 1036, 'date': None, 'customer_id': 'C135', 'quantity': 2, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'Oliver Sanchez', 'total_amount': 199.98, 'profit_margin': 0.24992499249924988}
# Warning: Date is None for record: {'sale_id': 1037, 'date': None, 'customer_id': 'C136', 'quantity': 4, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Lily Morris', 'total_amount': 119.96, 'profit_margin': 0.3331110370123374}
# Warning: Date is None for record: {'sale_id': 1038, 'date': None, 'customer_id': 'C137', 'quantity': 1, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'Henry Rogers', 'total_amount': 49.99, 'profit_margin': 0.2998599719943989}
# Warning: Date is None for record: {'sale_id': 1039, 'date': None, 'customer_id': 'C138', 'quantity': 5, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Ella Reed', 'total_amount': 79.95, 'profit_margin': 0.3746091307066917}
# Warning: Date is None for record: {'sale_id': 1040, 'date': None, 'customer_id': 'C139', 'quantity': 3, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'Samuel Cook', 'total_amount': 299.96999999999997, 'profit_margin': 0.24992499249924985}
# Warning: Date is None for record: {'sale_id': 1041, 'date': None, 'customer_id': 'C140', 'quantity': 2, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Madison Morgan', 'total_amount': 59.98, 'profit_margin': 0.3331110370123374}
# Warning: Date is None for record: {'sale_id': 1042, 'date': None, 'customer_id': 'C141', 'quantity': 4, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'Daniel Bell', 'total_amount': 199.96, 'profit_margin': 0.2998599719943989}
# Warning: Date is None for record: {'sale_id': 1043, 'date': None, 'customer_id': 'C142', 'quantity': 1, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Sofia Murphy', 'total_amount': 15.99, 'profit_margin': 0.3746091307066917}
# Warning: Date is None for record: {'sale_id': 1044, 'date': None, 'customer_id': 'C143', 'quantity': 5, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'Joseph Bailey', 'total_amount': 499.95, 'profit_margin': 0.2499249924992499}
# Warning: Date is None for record: {'sale_id': 1045, 'date': None, 'customer_id': 'C144', 'quantity': 3, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Hannah Rivera', 'total_amount': 89.97, 'profit_margin': 0.33311103701233746}
# Warning: Date is None for record: {'sale_id': 1046, 'date': None, 'customer_id': 'C145', 'quantity': 2, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'David Cooper', 'total_amount': 99.98, 'profit_margin': 0.2998599719943989}
# Warning: Date is None for record: {'sale_id': 1047, 'date': None, 'customer_id': 'C146', 'quantity': 4, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Aria Richardson', 'total_amount': 63.96, 'profit_margin': 0.3746091307066917}
# Warning: Date is None for record: {'sale_id': 1048, 'date': None, 'customer_id': 'C147', 'quantity': 1, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'Carter Cox', 'total_amount': 99.99, 'profit_margin': 0.24992499249924988}
# Warning: Date is None for record: {'sale_id': 1049, 'date': None, 'customer_id': 'C148', 'quantity': 5, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Scarlett Howard', 'total_amount': 149.95, 'profit_margin': 0.3331110370123374}
# Warning: Date is None for record: {'sale_id': 1050, 'date': None, 'customer_id': 'C149', 'quantity': 3, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'Owen Ward', 'total_amount': 149.97, 'profit_margin': 0.2998599719943989}
# Warning: Date is None for record: {'sale_id': 1051, 'date': None, 'customer_id': 'C150', 'quantity': 2, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Lillian Torres', 'total_amount': 31.98, 'profit_margin': 0.3746091307066917}
# Warning: Date is None for record: {'sale_id': 1052, 'date': None, 'customer_id': 'C151', 'quantity': 4, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'Wyatt Peterson', 'total_amount': 399.96, 'profit_margin': 0.24992499249924988}
# Warning: Date is None for record: {'sale_id': 1053, 'date': None, 'customer_id': 'C152', 'quantity': 1, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Ella Gray', 'total_amount': 29.99, 'profit_margin': 0.3331110370123374}
# Warning: Date is None for record: {'sale_id': 1054, 'date': None, 'customer_id': 'C153', 'quantity': 5, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'Jack Ramirez', 'total_amount': 249.95000000000002, 'profit_margin': 0.29985997199439895}
# Warning: Date is None for record: {'sale_id': 1055, 'date': None, 'customer_id': 'C154', 'quantity': 3, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Eleanor James', 'total_amount': 47.97, 'profit_margin': 0.37460913070669166}
# Warning: Date is None for record: {'sale_id': 1056, 'date': None, 'customer_id': 'C155', 'quantity': 2, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'Matthew Brooks', 'total_amount': 199.98, 'profit_margin': 0.24992499249924988}
# Warning: Date is None for record: {'sale_id': 1057, 'date': None, 'customer_id': 'C156', 'quantity': 4, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Avery Kelly', 'total_amount': 119.96, 'profit_margin': 0.3331110370123374}
# Warning: Date is None for record: {'sale_id': 1058, 'date': None, 'customer_id': 'C157', 'quantity': 1, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'Sebastian Sanders', 'total_amount': 49.99, 'profit_margin': 0.2998599719943989}
# Warning: Date is None for record: {'sale_id': 1059, 'date': None, 'customer_id': 'C158', 'quantity': 5, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Zoey Price', 'total_amount': 79.95, 'profit_margin': 0.3746091307066917}
# Warning: Date is None for record: {'sale_id': 1060, 'date': None, 'customer_id': 'C159', 'quantity': 3, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'Caleb Bennett', 'total_amount': 299.96999999999997, 'profit_margin': 0.24992499249924985}
# Warning: Date is None for record: {'sale_id': 1061, 'date': None, 'customer_id': 'C160', 'quantity': 2, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Nora Wood', 'total_amount': 59.98, 'profit_margin': 0.3331110370123374}
# Warning: Date is None for record: {'sale_id': 1062, 'date': None, 'customer_id': 'C161', 'quantity': 4, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'Andrew Barnes', 'total_amount': 199.96, 'profit_margin': 0.2998599719943989}
# Warning: Date is None for record: {'sale_id': 1063, 'date': None, 'customer_id': 'C162', 'quantity': 1, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Riley Ross', 'total_amount': 15.99, 'profit_margin': 0.3746091307066917}
# Warning: Date is None for record: {'sale_id': 1064, 'date': None, 'customer_id': 'C163', 'quantity': 5, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'Isaac Henderson', 'total_amount': 499.95, 'profit_margin': 0.2499249924992499}
# Warning: Date is None for record: {'sale_id': 1065, 'date': None, 'customer_id': 'C164', 'quantity': 3, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Samantha Coleman', 'total_amount': 89.97, 'profit_margin': 0.33311103701233746}
# Warning: Date is None for record: {'sale_id': 1066, 'date': None, 'customer_id': 'C165', 'quantity': 2, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'Ryan Jenkins', 'total_amount': 99.98, 'profit_margin': 0.2998599719943989}
# Warning: Date is None for record: {'sale_id': 1067, 'date': None, 'customer_id': 'C166', 'quantity': 4, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Leah Perry', 'total_amount': 63.96, 'profit_margin': 0.3746091307066917}
# Warning: Date is None for record: {'sale_id': 1068, 'date': None, 'customer_id': 'C167', 'quantity': 1, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'Christopher Powell', 'total_amount': 99.99, 'profit_margin': 0.24992499249924988}
# Warning: Date is None for record: {'sale_id': 1069, 'date': None, 'customer_id': 'C168', 'quantity': 5, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Audrey Long', 'total_amount': 149.95, 'profit_margin': 0.3331110370123374}
# Warning: Date is None for record: {'sale_id': 1070, 'date': None, 'customer_id': 'C169', 'quantity': 3, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'Nathan Patterson', 'total_amount': 149.97, 'profit_margin': 0.2998599719943989}
# Warning: Date is None for record: {'sale_id': 1071, 'date': None, 'customer_id': 'C170', 'quantity': 2, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Grace Hughes', 'total_amount': 31.98, 'profit_margin': 0.3746091307066917}
# Warning: Date is None for record: {'sale_id': 1072, 'date': None, 'customer_id': 'C171', 'quantity': 4, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'Thomas Flores', 'total_amount': 399.96, 'profit_margin': 0.24992499249924988}
# Warning: Date is None for record: {'sale_id': 1073, 'date': None, 'customer_id': 'C172', 'quantity': 1, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Violet Simmons', 'total_amount': 29.99, 'profit_margin': 0.3331110370123374}
# Warning: Date is None for record: {'sale_id': 1074, 'date': None, 'customer_id': 'C173', 'quantity': 5, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'Caleb Foster', 'total_amount': 249.95000000000002, 'profit_margin': 0.29985997199439895}
# Warning: Date is None for record: {'sale_id': 1075, 'date': None, 'customer_id': 'C174', 'quantity': 3, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Lily Butler', 'total_amount': 47.97, 'profit_margin': 0.37460913070669166}
# Warning: Date is None for record: {'sale_id': 1076, 'date': None, 'customer_id': 'C175', 'quantity': 2, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'Jonathan Richardson', 'total_amount': 199.98, 'profit_margin': 0.24992499249924988}
# Warning: Date is None for record: {'sale_id': 1077, 'date': None, 'customer_id': 'C176', 'quantity': 4, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Zoe Bryant', 'total_amount': 119.96, 'profit_margin': 0.3331110370123374}
# Warning: Date is None for record: {'sale_id': 1078, 'date': None, 'customer_id': 'C177', 'quantity': 1, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'Charles Alexander', 'total_amount': 49.99, 'profit_margin': 0.2998599719943989}
# Warning: Date is None for record: {'sale_id': 1079, 'date': None, 'customer_id': 'C178', 'quantity': 5, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Stella Russell', 'total_amount': 79.95, 'profit_margin': 0.3746091307066917}
# Warning: Date is None for record: {'sale_id': 1080, 'date': None, 'customer_id': 'C179', 'quantity': 3, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'Christian Griffin', 'total_amount': 299.96999999999997, 'profit_margin': 0.24992499249924985}
# Warning: Date is None for record: {'sale_id': 1081, 'date': None, 'customer_id': 'C180', 'quantity': 2, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Evelyn Diaz', 'total_amount': 59.98, 'profit_margin': 0.3331110370123374}
# Warning: Date is None for record: {'sale_id': 1082, 'date': None, 'customer_id': 'C181', 'quantity': 4, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'Aaron Hayes', 'total_amount': 199.96, 'profit_margin': 0.2998599719943989}
# Warning: Date is None for record: {'sale_id': 1083, 'date': None, 'customer_id': 'C182', 'quantity': 1, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Lucy Myers', 'total_amount': 15.99, 'profit_margin': 0.3746091307066917}
# Warning: Date is None for record: {'sale_id': 1084, 'date': None, 'customer_id': 'C183', 'quantity': 5, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'Adam Ford', 'total_amount': 499.95, 'profit_margin': 0.2499249924992499}
# Warning: Date is None for record: {'sale_id': 1085, 'date': None, 'customer_id': 'C184', 'quantity': 3, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Victoria Hamilton', 'total_amount': 89.97, 'profit_margin': 0.33311103701233746}
# Warning: Date is None for record: {'sale_id': 1086, 'date': None, 'customer_id': 'C185', 'quantity': 2, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'Isaiah Graham', 'total_amount': 99.98, 'profit_margin': 0.2998599719943989}
# Warning: Date is None for record: {'sale_id': 1087, 'date': None, 'customer_id': 'C186', 'quantity': 4, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Brooklyn Wallace', 'total_amount': 63.96, 'profit_margin': 0.3746091307066917}
# Warning: Date is None for record: {'sale_id': 1088, 'date': None, 'customer_id': 'C187', 'quantity': 1, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'Nicholas West', 'total_amount': 99.99, 'profit_margin': 0.24992499249924988}
# Warning: Date is None for record: {'sale_id': 1089, 'date': None, 'customer_id': 'C188', 'quantity': 5, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Anna Cole', 'total_amount': 149.95, 'profit_margin': 0.3331110370123374}
# Warning: Date is None for record: {'sale_id': 1090, 'date': None, 'customer_id': 'C189', 'quantity': 3, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'Jeremiah Jordan', 'total_amount': 149.97, 'profit_margin': 0.2998599719943989}
# Warning: Date is None for record: {'sale_id': 1091, 'date': None, 'customer_id': 'C190', 'quantity': 2, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Hazel Reynolds', 'total_amount': 31.98, 'profit_margin': 0.3746091307066917}
# Warning: Date is None for record: {'sale_id': 1092, 'date': None, 'customer_id': 'C191', 'quantity': 4, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'Joshua Fisher', 'total_amount': 399.96, 'profit_margin': 0.24992499249924988}
# Warning: Date is None for record: {'sale_id': 1093, 'date': None, 'customer_id': 'C192', 'quantity': 1, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Claire Kim', 'total_amount': 29.99, 'profit_margin': 0.3331110370123374}
# Warning: Date is None for record: {'sale_id': 1094, 'date': None, 'customer_id': 'C193', 'quantity': 5, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'Levi Butler', 'total_amount': 249.95000000000002, 'profit_margin': 0.29985997199439895}
# Warning: Date is None for record: {'sale_id': 1095, 'date': None, 'customer_id': 'C194', 'quantity': 3, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Aria Bennett', 'total_amount': 47.97, 'profit_margin': 0.37460913070669166}
# Warning: Date is None for record: {'sale_id': 1096, 'date': None, 'customer_id': 'C195', 'quantity': 2, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'David Cox', 'total_amount': 199.98, 'profit_margin': 0.24992499249924988}
# Warning: Date is None for record: {'sale_id': 1097, 'date': None, 'customer_id': 'C196', 'quantity': 4, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Scarlett Nguyen', 'total_amount': 119.96, 'profit_margin': 0.3331110370123374}
# Warning: Date is None for record: {'sale_id': 1098, 'date': None, 'customer_id': 'C197', 'quantity': 1, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'Isaac Brooks', 'total_amount': 49.99, 'profit_margin': 0.2998599719943989}
# Warning: Date is None for record: {'sale_id': 1099, 'date': None, 'customer_id': 'C198', 'quantity': 5, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Luna Ward', 'total_amount': 79.95, 'profit_margin': 0.3746091307066917}
# Warning: Date is None for record: {'sale_id': 1100, 'date': None, 'customer_id': 'C199', 'quantity': 3, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'Julian Torres', 'total_amount': 299.96999999999997, 'profit_margin': 0.24992499249924985}
# Warning: Date is None for record: {'sale_id': 1101, 'date': None, 'customer_id': 'C200', 'quantity': 2, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Sadie Peterson', 'total_amount': 59.98, 'profit_margin': 0.3331110370123374}
# Warning: Date is None for record: {'sale_id': 1102, 'date': None, 'customer_id': 'C101', 'quantity': 4, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'Alex Johnson', 'total_amount': 199.96, 'profit_margin': 0.2998599719943989}
# Warning: Date is None for record: {'sale_id': 1103, 'date': None, 'customer_id': 'C102', 'quantity': 1, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Emily Davis', 'total_amount': 15.99, 'profit_margin': 0.3746091307066917}
# Warning: Date is None for record: {'sale_id': 1104, 'date': None, 'customer_id': 'C103', 'quantity': 5, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'Michael Brown', 'total_amount': 499.95, 'profit_margin': 0.2499249924992499}
# Warning: Date is None for record: {'sale_id': 1105, 'date': None, 'customer_id': 'C104', 'quantity': 3, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Sophia Wilson', 'total_amount': 89.97, 'profit_margin': 0.33311103701233746}
# Warning: Date is None for record: {'sale_id': 1106, 'date': None, 'customer_id': 'C105', 'quantity': 2, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'Daniel Smith', 'total_amount': 99.98, 'profit_margin': 0.2998599719943989}
# Warning: Date is None for record: {'sale_id': 1107, 'date': None, 'customer_id': 'C106', 'quantity': 4, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Olivia Martin', 'total_amount': 63.96, 'profit_margin': 0.3746091307066917}
# Warning: Date is None for record: {'sale_id': 1108, 'date': None, 'customer_id': 'C107', 'quantity': 1, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'Matthew Clark', 'total_amount': 99.99, 'profit_margin': 0.24992499249924988}
# Warning: Date is None for record: {'sale_id': 1109, 'date': None, 'customer_id': 'C108', 'quantity': 5, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Isabella Lewis', 'total_amount': 149.95, 'profit_margin': 0.3331110370123374}
# Warning: Date is None for record: {'sale_id': 1110, 'date': None, 'customer_id': 'C109', 'quantity': 3, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'Ethan Walker', 'total_amount': 149.97, 'profit_margin': 0.2998599719943989}
# Warning: Date is None for record: {'sale_id': 1111, 'date': None, 'customer_id': 'C110', 'quantity': 2, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Mia Hall', 'total_amount': 31.98, 'profit_margin': 0.3746091307066917}
# Warning: Date is None for record: {'sale_id': 1112, 'date': None, 'customer_id': 'C111', 'quantity': 4, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'William Young', 'total_amount': 399.96, 'profit_margin': 0.24992499249924988}
# Warning: Date is None for record: {'sale_id': 1113, 'date': None, 'customer_id': 'C112', 'quantity': 1, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Ava Hernandez', 'total_amount': 29.99, 'profit_margin': 0.3331110370123374}
# Warning: Date is None for record: {'sale_id': 1114, 'date': None, 'customer_id': 'C113', 'quantity': 5, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'James King', 'total_amount': 249.95000000000002, 'profit_margin': 0.29985997199439895}
# Warning: Date is None for record: {'sale_id': 1115, 'date': None, 'customer_id': 'C114', 'quantity': 3, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Charlotte Wright', 'total_amount': 47.97, 'profit_margin': 0.37460913070669166}
# Warning: Date is None for record: {'sale_id': 1116, 'date': None, 'customer_id': 'C115', 'quantity': 2, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'Logan Lopez', 'total_amount': 199.98, 'profit_margin': 0.24992499249924988}
# Warning: Date is None for record: {'sale_id': 1117, 'date': None, 'customer_id': 'C116', 'quantity': 4, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Amelia Hill', 'total_amount': 119.96, 'profit_margin': 0.3331110370123374}
# Warning: Date is None for record: {'sale_id': 1118, 'date': None, 'customer_id': 'C117', 'quantity': 1, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'Benjamin Scott', 'total_amount': 49.99, 'profit_margin': 0.2998599719943989}
# Warning: Date is None for record: {'sale_id': 1119, 'date': None, 'customer_id': 'C118', 'quantity': 5, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Evelyn Green', 'total_amount': 79.95, 'profit_margin': 0.3746091307066917}
# Warning: Date is None for record: {'sale_id': 1120, 'date': None, 'customer_id': 'C119', 'quantity': 3, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'Jacob Adams', 'total_amount': 299.96999999999997, 'profit_margin': 0.24992499249924985}
# Warning: Date is None for record: {'sale_id': 1122, 'date': None, 'customer_id': 'C121', 'quantity': 4, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'Alexander Gonzalez', 'total_amount': 199.96, 'profit_margin': 0.2998599719943989}
# Warning: Date is None for record: {'sale_id': 1123, 'date': None, 'customer_id': 'C122', 'quantity': 1, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Abigail Nelson', 'total_amount': 15.99, 'profit_margin': 0.3746091307066917}
# Warning: Date is None for record: {'sale_id': 1124, 'date': None, 'customer_id': 'C123', 'quantity': 5, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'Jackson Carter', 'total_amount': 499.95, 'profit_margin': 0.2499249924992499}
# Warning: Date is None for record: {'sale_id': 1125, 'date': None, 'customer_id': 'C124', 'quantity': 3, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Emily Mitchell', 'total_amount': 89.97, 'profit_margin': 0.33311103701233746}
#
# Daily Sales Trends:
#
# Monthly Sales Trends:
#
# Quarterly Sales Trends:

# %%
# Check for records with None dates
missing_date_records = [record for record in integrated_sales_data if record.get('date') is None]

if missing_date_records:
    print("Records with missing dates:")
    for record in missing_date_records:
        print(record)

# Proceed with the analysis only if there are no missing date records
if not missing_date_records:
    # Initialize dictionaries to hold sales data for trends
    daily_sales = defaultdict(float)
    monthly_sales = defaultdict(float)
    quarterly_sales = defaultdict(float)

    # Iterate through the integrated sales data to calculate sales trends
    for record in integrated_sales_data:
        date = record.get('date')  # Safely get the date
        if date is None:
            print("Warning: Date is None for record:", record)
            continue  # Skip this record

        # Convert date from dd-mm-yyyy to yyyy-mm-dd
        try:
            date_obj = datetime.strptime(date, '%d-%m-%Y')
            formatted_date = date_obj.strftime('%Y-%m-%d')
        except ValueError as e:
            print(f"Error parsing date '{date}': {e}")
            continue  # Skip this record if date parsing fails

        # Daily sales
        daily_sales[formatted_date] += record['total_amount']

        # Monthly sales
        month = formatted_date[:7]  # Extract YYYY-MM format
        monthly_sales[month] += record['total_amount']

        # Quarterly sales
        year = formatted_date[:4]
        month_num = int(formatted_date[5:7])
        quarter = (month_num - 1) // 3 + 1
        quarterly_key = f"{year}-Q{quarter}"
        quarterly_sales[quarterly_key] += record['total_amount']

    # Print daily sales trends
    print("\nDaily Sales Trends:")
    for date, total in sorted(daily_sales.items()):
        print(f"Date: {date}, Total Sales: {total:.2f}")

    # Print monthly sales trends
    print("\nMonthly Sales Trends:")
    for month, total in sorted(monthly_sales.items()):
        print(f"Month: {month}, Total Sales: {total:.2f}")

    # Print quarterly sales trends
    print("\nQuarterly Sales Trends:")
    for quarter, total in sorted(quarterly_sales.items()):
        print(f"Quarter: {quarter}, Total Sales: {total:.2f}")
else:
    print("Analysis cannot proceed due to missing date records.")
# Out:
# Records with missing dates:
# {'sale_id': 1001, 'date': None, 'customer_id': 'C101', 'quantity': 2, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Alex Johnson', 'total_amount': 59.98, 'profit_margin': 0.3331110370123374}
# {'sale_id': 1002, 'date': None, 'customer_id': 'C102', 'quantity': 1, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'Emily Davis', 'total_amount': 49.99, 'profit_margin': 0.2998599719943989}
# {'sale_id': 1003, 'date': None, 'customer_id': 'C103', 'quantity': 3, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Michael Brown', 'total_amount': 47.97, 'profit_margin': 0.37460913070669166}
# {'sale_id': 1004, 'date': None, 'customer_id': 'C101', 'quantity': 1, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'Alex Johnson', 'total_amount': 99.99, 'profit_margin': 0.24992499249924988}
# {'sale_id': 1005, 'date': None, 'customer_id': 'C104', 'quantity': 2, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Sophia Wilson', 'total_amount': 59.98, 'profit_margin': 0.3331110370123374}
# {'sale_id': 1006, 'date': None, 'customer_id': 'C105', 'quantity': 4, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'Daniel Smith', 'total_amount': 199.96, 'profit_margin': 0.2998599719943989}
# {'sale_id': 1007, 'date': None, 'customer_id': 'C106', 'quantity': 1, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Olivia Martin', 'total_amount': 15.99, 'profit_margin': 0.3746091307066917}
# {'sale_id': 1008, 'date': None, 'customer_id': 'C107', 'quantity': 5, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'Matthew Clark', 'total_amount': 499.95, 'profit_margin': 0.2499249924992499}
# {'sale_id': 1009, 'date': None, 'customer_id': 'C108', 'quantity': 2, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Isabella Lewis', 'total_amount': 59.98, 'profit_margin': 0.3331110370123374}
# {'sale_id': 1010, 'date': None, 'customer_id': 'C109', 'quantity': 3, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'Ethan Walker', 'total_amount': 149.97, 'profit_margin': 0.2998599719943989}
# {'sale_id': 1011, 'date': None, 'customer_id': 'C110', 'quantity': 2, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Mia Hall', 'total_amount': 31.98, 'profit_margin': 0.3746091307066917}
# {'sale_id': 1012, 'date': None, 'customer_id': 'C111', 'quantity': 4, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'William Young', 'total_amount': 399.96, 'profit_margin': 0.24992499249924988}
# {'sale_id': 1013, 'date': None, 'customer_id': 'C112', 'quantity': 1, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Ava Hernandez', 'total_amount': 29.99, 'profit_margin': 0.3331110370123374}
# {'sale_id': 1014, 'date': None, 'customer_id': 'C113', 'quantity': 5, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'James King', 'total_amount': 249.95000000000002, 'profit_margin': 0.29985997199439895}
# {'sale_id': 1015, 'date': None, 'customer_id': 'C114', 'quantity': 3, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Charlotte Wright', 'total_amount': 47.97, 'profit_margin': 0.37460913070669166}
# {'sale_id': 1016, 'date': None, 'customer_id': 'C115', 'quantity': 2, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'Logan Lopez', 'total_amount': 199.98, 'profit_margin': 0.24992499249924988}
# {'sale_id': 1017, 'date': None, 'customer_id': 'C116', 'quantity': 4, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Amelia Hill', 'total_amount': 119.96, 'profit_margin': 0.3331110370123374}
# {'sale_id': 1018, 'date': None, 'customer_id': 'C117', 'quantity': 1, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'Benjamin Scott', 'total_amount': 49.99, 'profit_margin': 0.2998599719943989}
# {'sale_id': 1019, 'date': None, 'customer_id': 'C118', 'quantity': 5, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Evelyn Green', 'total_amount': 79.95, 'profit_margin': 0.3746091307066917}
# {'sale_id': 1020, 'date': None, 'customer_id': 'C119', 'quantity': 3, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'Jacob Adams', 'total_amount': 299.96999999999997, 'profit_margin': 0.24992499249924985}
# {'sale_id': 1022, 'date': None, 'customer_id': 'C121', 'quantity': 4, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'Alexander Gonzalez', 'total_amount': 199.96, 'profit_margin': 0.2998599719943989}
# {'sale_id': 1023, 'date': None, 'customer_id': 'C122', 'quantity': 1, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Abigail Nelson', 'total_amount': 15.99, 'profit_margin': 0.3746091307066917}
# {'sale_id': 1024, 'date': None, 'customer_id': 'C123', 'quantity': 5, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'Jackson Carter', 'total_amount': 499.95, 'profit_margin': 0.2499249924992499}
# {'sale_id': 1025, 'date': None, 'customer_id': 'C124', 'quantity': 3, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Emily Mitchell', 'total_amount': 89.97, 'profit_margin': 0.33311103701233746}
# {'sale_id': 1026, 'date': None, 'customer_id': 'C125', 'quantity': 2, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'Liam Perez', 'total_amount': 99.98, 'profit_margin': 0.2998599719943989}
# {'sale_id': 1027, 'date': None, 'customer_id': 'C126', 'quantity': 4, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Sophia Roberts', 'total_amount': 63.96, 'profit_margin': 0.3746091307066917}
# {'sale_id': 1028, 'date': None, 'customer_id': 'C127', 'quantity': 1, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'Noah Turner', 'total_amount': 99.99, 'profit_margin': 0.24992499249924988}
# {'sale_id': 1029, 'date': None, 'customer_id': 'C128', 'quantity': 5, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Grace Phillips', 'total_amount': 149.95, 'profit_margin': 0.3331110370123374}
# {'sale_id': 1030, 'date': None, 'customer_id': 'C129', 'quantity': 3, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'Elijah Campbell', 'total_amount': 149.97, 'profit_margin': 0.2998599719943989}
# {'sale_id': 1031, 'date': None, 'customer_id': 'C130', 'quantity': 2, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Chloe Parker', 'total_amount': 31.98, 'profit_margin': 0.3746091307066917}
# {'sale_id': 1032, 'date': None, 'customer_id': 'C131', 'quantity': 4, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'Aiden Evans', 'total_amount': 399.96, 'profit_margin': 0.24992499249924988}
# {'sale_id': 1033, 'date': None, 'customer_id': 'C132', 'quantity': 1, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Victoria Edwards', 'total_amount': 29.99, 'profit_margin': 0.3331110370123374}
# {'sale_id': 1034, 'date': None, 'customer_id': 'C133', 'quantity': 5, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'Lucas Collins', 'total_amount': 249.95000000000002, 'profit_margin': 0.29985997199439895}
# {'sale_id': 1035, 'date': None, 'customer_id': 'C134', 'quantity': 3, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Penelope Stewart', 'total_amount': 47.97, 'profit_margin': 0.37460913070669166}
# {'sale_id': 1036, 'date': None, 'customer_id': 'C135', 'quantity': 2, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'Oliver Sanchez', 'total_amount': 199.98, 'profit_margin': 0.24992499249924988}
# {'sale_id': 1037, 'date': None, 'customer_id': 'C136', 'quantity': 4, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Lily Morris', 'total_amount': 119.96, 'profit_margin': 0.3331110370123374}
# {'sale_id': 1038, 'date': None, 'customer_id': 'C137', 'quantity': 1, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'Henry Rogers', 'total_amount': 49.99, 'profit_margin': 0.2998599719943989}
# {'sale_id': 1039, 'date': None, 'customer_id': 'C138', 'quantity': 5, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Ella Reed', 'total_amount': 79.95, 'profit_margin': 0.3746091307066917}
# {'sale_id': 1040, 'date': None, 'customer_id': 'C139', 'quantity': 3, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'Samuel Cook', 'total_amount': 299.96999999999997, 'profit_margin': 0.24992499249924985}
# {'sale_id': 1041, 'date': None, 'customer_id': 'C140', 'quantity': 2, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Madison Morgan', 'total_amount': 59.98, 'profit_margin': 0.3331110370123374}
# {'sale_id': 1042, 'date': None, 'customer_id': 'C141', 'quantity': 4, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'Daniel Bell', 'total_amount': 199.96, 'profit_margin': 0.2998599719943989}
# {'sale_id': 1043, 'date': None, 'customer_id': 'C142', 'quantity': 1, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Sofia Murphy', 'total_amount': 15.99, 'profit_margin': 0.3746091307066917}
# {'sale_id': 1044, 'date': None, 'customer_id': 'C143', 'quantity': 5, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'Joseph Bailey', 'total_amount': 499.95, 'profit_margin': 0.2499249924992499}
# {'sale_id': 1045, 'date': None, 'customer_id': 'C144', 'quantity': 3, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Hannah Rivera', 'total_amount': 89.97, 'profit_margin': 0.33311103701233746}
# {'sale_id': 1046, 'date': None, 'customer_id': 'C145', 'quantity': 2, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'David Cooper', 'total_amount': 99.98, 'profit_margin': 0.2998599719943989}
# {'sale_id': 1047, 'date': None, 'customer_id': 'C146', 'quantity': 4, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Aria Richardson', 'total_amount': 63.96, 'profit_margin': 0.3746091307066917}
# {'sale_id': 1048, 'date': None, 'customer_id': 'C147', 'quantity': 1, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'Carter Cox', 'total_amount': 99.99, 'profit_margin': 0.24992499249924988}
# {'sale_id': 1049, 'date': None, 'customer_id': 'C148', 'quantity': 5, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Scarlett Howard', 'total_amount': 149.95, 'profit_margin': 0.3331110370123374}
# {'sale_id': 1050, 'date': None, 'customer_id': 'C149', 'quantity': 3, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'Owen Ward', 'total_amount': 149.97, 'profit_margin': 0.2998599719943989}
# {'sale_id': 1051, 'date': None, 'customer_id': 'C150', 'quantity': 2, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Lillian Torres', 'total_amount': 31.98, 'profit_margin': 0.3746091307066917}
# {'sale_id': 1052, 'date': None, 'customer_id': 'C151', 'quantity': 4, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'Wyatt Peterson', 'total_amount': 399.96, 'profit_margin': 0.24992499249924988}
# {'sale_id': 1053, 'date': None, 'customer_id': 'C152', 'quantity': 1, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Ella Gray', 'total_amount': 29.99, 'profit_margin': 0.3331110370123374}
# {'sale_id': 1054, 'date': None, 'customer_id': 'C153', 'quantity': 5, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'Jack Ramirez', 'total_amount': 249.95000000000002, 'profit_margin': 0.29985997199439895}
# {'sale_id': 1055, 'date': None, 'customer_id': 'C154', 'quantity': 3, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Eleanor James', 'total_amount': 47.97, 'profit_margin': 0.37460913070669166}
# {'sale_id': 1056, 'date': None, 'customer_id': 'C155', 'quantity': 2, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'Matthew Brooks', 'total_amount': 199.98, 'profit_margin': 0.24992499249924988}
# {'sale_id': 1057, 'date': None, 'customer_id': 'C156', 'quantity': 4, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Avery Kelly', 'total_amount': 119.96, 'profit_margin': 0.3331110370123374}
# {'sale_id': 1058, 'date': None, 'customer_id': 'C157', 'quantity': 1, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'Sebastian Sanders', 'total_amount': 49.99, 'profit_margin': 0.2998599719943989}
# {'sale_id': 1059, 'date': None, 'customer_id': 'C158', 'quantity': 5, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Zoey Price', 'total_amount': 79.95, 'profit_margin': 0.3746091307066917}
# {'sale_id': 1060, 'date': None, 'customer_id': 'C159', 'quantity': 3, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'Caleb Bennett', 'total_amount': 299.96999999999997, 'profit_margin': 0.24992499249924985}
# {'sale_id': 1061, 'date': None, 'customer_id': 'C160', 'quantity': 2, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Nora Wood', 'total_amount': 59.98, 'profit_margin': 0.3331110370123374}
# {'sale_id': 1062, 'date': None, 'customer_id': 'C161', 'quantity': 4, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'Andrew Barnes', 'total_amount': 199.96, 'profit_margin': 0.2998599719943989}
# {'sale_id': 1063, 'date': None, 'customer_id': 'C162', 'quantity': 1, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Riley Ross', 'total_amount': 15.99, 'profit_margin': 0.3746091307066917}
# {'sale_id': 1064, 'date': None, 'customer_id': 'C163', 'quantity': 5, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'Isaac Henderson', 'total_amount': 499.95, 'profit_margin': 0.2499249924992499}
# {'sale_id': 1065, 'date': None, 'customer_id': 'C164', 'quantity': 3, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Samantha Coleman', 'total_amount': 89.97, 'profit_margin': 0.33311103701233746}
# {'sale_id': 1066, 'date': None, 'customer_id': 'C165', 'quantity': 2, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'Ryan Jenkins', 'total_amount': 99.98, 'profit_margin': 0.2998599719943989}
# {'sale_id': 1067, 'date': None, 'customer_id': 'C166', 'quantity': 4, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Leah Perry', 'total_amount': 63.96, 'profit_margin': 0.3746091307066917}
# {'sale_id': 1068, 'date': None, 'customer_id': 'C167', 'quantity': 1, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'Christopher Powell', 'total_amount': 99.99, 'profit_margin': 0.24992499249924988}
# {'sale_id': 1069, 'date': None, 'customer_id': 'C168', 'quantity': 5, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Audrey Long', 'total_amount': 149.95, 'profit_margin': 0.3331110370123374}
# {'sale_id': 1070, 'date': None, 'customer_id': 'C169', 'quantity': 3, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'Nathan Patterson', 'total_amount': 149.97, 'profit_margin': 0.2998599719943989}
# {'sale_id': 1071, 'date': None, 'customer_id': 'C170', 'quantity': 2, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Grace Hughes', 'total_amount': 31.98, 'profit_margin': 0.3746091307066917}
# {'sale_id': 1072, 'date': None, 'customer_id': 'C171', 'quantity': 4, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'Thomas Flores', 'total_amount': 399.96, 'profit_margin': 0.24992499249924988}
# {'sale_id': 1073, 'date': None, 'customer_id': 'C172', 'quantity': 1, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Violet Simmons', 'total_amount': 29.99, 'profit_margin': 0.3331110370123374}
# {'sale_id': 1074, 'date': None, 'customer_id': 'C173', 'quantity': 5, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'Caleb Foster', 'total_amount': 249.95000000000002, 'profit_margin': 0.29985997199439895}
# {'sale_id': 1075, 'date': None, 'customer_id': 'C174', 'quantity': 3, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Lily Butler', 'total_amount': 47.97, 'profit_margin': 0.37460913070669166}
# {'sale_id': 1076, 'date': None, 'customer_id': 'C175', 'quantity': 2, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'Jonathan Richardson', 'total_amount': 199.98, 'profit_margin': 0.24992499249924988}
# {'sale_id': 1077, 'date': None, 'customer_id': 'C176', 'quantity': 4, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Zoe Bryant', 'total_amount': 119.96, 'profit_margin': 0.3331110370123374}
# {'sale_id': 1078, 'date': None, 'customer_id': 'C177', 'quantity': 1, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'Charles Alexander', 'total_amount': 49.99, 'profit_margin': 0.2998599719943989}
# {'sale_id': 1079, 'date': None, 'customer_id': 'C178', 'quantity': 5, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Stella Russell', 'total_amount': 79.95, 'profit_margin': 0.3746091307066917}
# {'sale_id': 1080, 'date': None, 'customer_id': 'C179', 'quantity': 3, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'Christian Griffin', 'total_amount': 299.96999999999997, 'profit_margin': 0.24992499249924985}
# {'sale_id': 1081, 'date': None, 'customer_id': 'C180', 'quantity': 2, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Evelyn Diaz', 'total_amount': 59.98, 'profit_margin': 0.3331110370123374}
# {'sale_id': 1082, 'date': None, 'customer_id': 'C181', 'quantity': 4, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'Aaron Hayes', 'total_amount': 199.96, 'profit_margin': 0.2998599719943989}
# {'sale_id': 1083, 'date': None, 'customer_id': 'C182', 'quantity': 1, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Lucy Myers', 'total_amount': 15.99, 'profit_margin': 0.3746091307066917}
# {'sale_id': 1084, 'date': None, 'customer_id': 'C183', 'quantity': 5, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'Adam Ford', 'total_amount': 499.95, 'profit_margin': 0.2499249924992499}
# {'sale_id': 1085, 'date': None, 'customer_id': 'C184', 'quantity': 3, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Victoria Hamilton', 'total_amount': 89.97, 'profit_margin': 0.33311103701233746}
# {'sale_id': 1086, 'date': None, 'customer_id': 'C185', 'quantity': 2, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'Isaiah Graham', 'total_amount': 99.98, 'profit_margin': 0.2998599719943989}
# {'sale_id': 1087, 'date': None, 'customer_id': 'C186', 'quantity': 4, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Brooklyn Wallace', 'total_amount': 63.96, 'profit_margin': 0.3746091307066917}
# {'sale_id': 1088, 'date': None, 'customer_id': 'C187', 'quantity': 1, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'Nicholas West', 'total_amount': 99.99, 'profit_margin': 0.24992499249924988}
# {'sale_id': 1089, 'date': None, 'customer_id': 'C188', 'quantity': 5, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Anna Cole', 'total_amount': 149.95, 'profit_margin': 0.3331110370123374}
# {'sale_id': 1090, 'date': None, 'customer_id': 'C189', 'quantity': 3, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'Jeremiah Jordan', 'total_amount': 149.97, 'profit_margin': 0.2998599719943989}
# {'sale_id': 1091, 'date': None, 'customer_id': 'C190', 'quantity': 2, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Hazel Reynolds', 'total_amount': 31.98, 'profit_margin': 0.3746091307066917}
# {'sale_id': 1092, 'date': None, 'customer_id': 'C191', 'quantity': 4, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'Joshua Fisher', 'total_amount': 399.96, 'profit_margin': 0.24992499249924988}
# {'sale_id': 1093, 'date': None, 'customer_id': 'C192', 'quantity': 1, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Claire Kim', 'total_amount': 29.99, 'profit_margin': 0.3331110370123374}
# {'sale_id': 1094, 'date': None, 'customer_id': 'C193', 'quantity': 5, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'Levi Butler', 'total_amount': 249.95000000000002, 'profit_margin': 0.29985997199439895}
# {'sale_id': 1095, 'date': None, 'customer_id': 'C194', 'quantity': 3, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Aria Bennett', 'total_amount': 47.97, 'profit_margin': 0.37460913070669166}
# {'sale_id': 1096, 'date': None, 'customer_id': 'C195', 'quantity': 2, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'David Cox', 'total_amount': 199.98, 'profit_margin': 0.24992499249924988}
# {'sale_id': 1097, 'date': None, 'customer_id': 'C196', 'quantity': 4, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Scarlett Nguyen', 'total_amount': 119.96, 'profit_margin': 0.3331110370123374}
# {'sale_id': 1098, 'date': None, 'customer_id': 'C197', 'quantity': 1, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'Isaac Brooks', 'total_amount': 49.99, 'profit_margin': 0.2998599719943989}
# {'sale_id': 1099, 'date': None, 'customer_id': 'C198', 'quantity': 5, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Luna Ward', 'total_amount': 79.95, 'profit_margin': 0.3746091307066917}
# {'sale_id': 1100, 'date': None, 'customer_id': 'C199', 'quantity': 3, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'Julian Torres', 'total_amount': 299.96999999999997, 'profit_margin': 0.24992499249924985}
# {'sale_id': 1101, 'date': None, 'customer_id': 'C200', 'quantity': 2, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Sadie Peterson', 'total_amount': 59.98, 'profit_margin': 0.3331110370123374}
# {'sale_id': 1102, 'date': None, 'customer_id': 'C101', 'quantity': 4, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'Alex Johnson', 'total_amount': 199.96, 'profit_margin': 0.2998599719943989}
# {'sale_id': 1103, 'date': None, 'customer_id': 'C102', 'quantity': 1, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Emily Davis', 'total_amount': 15.99, 'profit_margin': 0.3746091307066917}
# {'sale_id': 1104, 'date': None, 'customer_id': 'C103', 'quantity': 5, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'Michael Brown', 'total_amount': 499.95, 'profit_margin': 0.2499249924992499}
# {'sale_id': 1105, 'date': None, 'customer_id': 'C104', 'quantity': 3, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Sophia Wilson', 'total_amount': 89.97, 'profit_margin': 0.33311103701233746}
# {'sale_id': 1106, 'date': None, 'customer_id': 'C105', 'quantity': 2, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'Daniel Smith', 'total_amount': 99.98, 'profit_margin': 0.2998599719943989}
# {'sale_id': 1107, 'date': None, 'customer_id': 'C106', 'quantity': 4, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Olivia Martin', 'total_amount': 63.96, 'profit_margin': 0.3746091307066917}
# {'sale_id': 1108, 'date': None, 'customer_id': 'C107', 'quantity': 1, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'Matthew Clark', 'total_amount': 99.99, 'profit_margin': 0.24992499249924988}
# {'sale_id': 1109, 'date': None, 'customer_id': 'C108', 'quantity': 5, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Isabella Lewis', 'total_amount': 149.95, 'profit_margin': 0.3331110370123374}
# {'sale_id': 1110, 'date': None, 'customer_id': 'C109', 'quantity': 3, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'Ethan Walker', 'total_amount': 149.97, 'profit_margin': 0.2998599719943989}
# {'sale_id': 1111, 'date': None, 'customer_id': 'C110', 'quantity': 2, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Mia Hall', 'total_amount': 31.98, 'profit_margin': 0.3746091307066917}
# {'sale_id': 1112, 'date': None, 'customer_id': 'C111', 'quantity': 4, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'William Young', 'total_amount': 399.96, 'profit_margin': 0.24992499249924988}
# {'sale_id': 1113, 'date': None, 'customer_id': 'C112', 'quantity': 1, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Ava Hernandez', 'total_amount': 29.99, 'profit_margin': 0.3331110370123374}
# {'sale_id': 1114, 'date': None, 'customer_id': 'C113', 'quantity': 5, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'James King', 'total_amount': 249.95000000000002, 'profit_margin': 0.29985997199439895}
# {'sale_id': 1115, 'date': None, 'customer_id': 'C114', 'quantity': 3, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Charlotte Wright', 'total_amount': 47.97, 'profit_margin': 0.37460913070669166}
# {'sale_id': 1116, 'date': None, 'customer_id': 'C115', 'quantity': 2, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'Logan Lopez', 'total_amount': 199.98, 'profit_margin': 0.24992499249924988}
# {'sale_id': 1117, 'date': None, 'customer_id': 'C116', 'quantity': 4, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Amelia Hill', 'total_amount': 119.96, 'profit_margin': 0.3331110370123374}
# {'sale_id': 1118, 'date': None, 'customer_id': 'C117', 'quantity': 1, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'Benjamin Scott', 'total_amount': 49.99, 'profit_margin': 0.2998599719943989}
# {'sale_id': 1119, 'date': None, 'customer_id': 'C118', 'quantity': 5, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Evelyn Green', 'total_amount': 79.95, 'profit_margin': 0.3746091307066917}
# {'sale_id': 1120, 'date': None, 'customer_id': 'C119', 'quantity': 3, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'Jacob Adams', 'total_amount': 299.96999999999997, 'profit_margin': 0.24992499249924985}
# {'sale_id': 1122, 'date': None, 'customer_id': 'C121', 'quantity': 4, 'price': 49.99, 'product_id': 'P202', 'product_name': 'LED Desk Lamp', 'category': 'Home & Office', 'customer_name': 'Alexander Gonzalez', 'total_amount': 199.96, 'profit_margin': 0.2998599719943989}
# {'sale_id': 1123, 'date': None, 'customer_id': 'C122', 'quantity': 1, 'price': 15.99, 'product_id': 'P203', 'product_name': 'Notebook Set', 'category': 'Stationery', 'customer_name': 'Abigail Nelson', 'total_amount': 15.99, 'profit_margin': 0.3746091307066917}
# {'sale_id': 1124, 'date': None, 'customer_id': 'C123', 'quantity': 5, 'price': 99.99, 'product_id': 'P204', 'product_name': 'Bluetooth Speaker', 'category': 'Electronics', 'customer_name': 'Jackson Carter', 'total_amount': 499.95, 'profit_margin': 0.2499249924992499}
# {'sale_id': 1125, 'date': None, 'customer_id': 'C124', 'quantity': 3, 'price': 29.99, 'product_id': 'P201', 'product_name': 'Wireless Mouse', 'category': 'Electronics', 'customer_name': 'Emily Mitchell', 'total_amount': 89.97, 'profit_margin': 0.33311103701233746}
# Analysis cannot proceed due to missing date records.
